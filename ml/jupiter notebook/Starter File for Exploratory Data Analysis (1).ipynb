# %% [markdown]
# ##### Step 1: Prelimenaries

# %% [markdown]
# Download the dataset [here](https://github.com/bidhanchan/MLOPC-IIMS)

# %% [markdown]
# Import the necessary libraries. (pandas and OS )

# %%
import os
import pandas as pd;

# %% [markdown]
# Load the dataset into a dataframe. (the syntax to load a csv file is read_csv)

# %%
all_data=pd.read_csv("all_data.csv")
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# Display the first 5 rows of a dataframe.

# %%
all_data.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
# 6   176562        USB-C Charging Cable                1      11.95
# 7   176563  Bose SoundSport Headphones                1      99.99
# 8   176564        USB-C Charging Cable                1      11.95
# 9   176565          Macbook Pro Laptop                1       1700
#
#        Order Date                        Purchase Address
# 0  04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1             NaN                                     NaN
# ...

# %% [markdown]
# Display the last 5 rows of the dataframe.

# %%
all_data.tail(10)
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 186840   259349    AAA Batteries (4-pack)                1       2.99
# 186841   259350              Google Phone                1        600
# 186842   259350      USB-C Charging Cable                1      11.95
# 186843   259351  Apple Airpods Headphones                1        150
# 186844   259352      USB-C Charging Cable                1      11.95
# 186845   259353    AAA Batteries (4-pack)                3       2.99
# 186846   259354                    iPhone                1        700
# 186847   259355                    iPhone                1        700
# 186848   259356    34in Ultrawide Monitor                1     379.99
# 186849   259357      USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 186840  09/01/19 22:14           911 River St, Dallas, TX 75001
# 186841  09/30/19 13:49    519 Maple St, San Francisco, CA 94016
# ...

# %% [markdown]
# ##### Step 2: Data Cleaning

# %% [markdown]
# One important thing about data cleaning is that you will need to clean your data at multiple stages of the program. This is a never ending task. (so, beome good at it)

# %% [markdown]
# Drop rows of nan (For this use the dropna command, but there is a bit of preprocessing we need to do before we get there). I want you to only drop the rows which have nan across all columns.
# Hint: You will have to list the nan values first, before removing them

# %%
nandf=all_data[all_data.isna().all(axis=1)]
nandf
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1           NaN     NaN              NaN        NaN        NaN
# 356         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1433        NaN     NaN              NaN        NaN        NaN
# 1553        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185176      NaN     NaN              NaN        NaN        NaN
# 185438      NaN     NaN              NaN        NaN        NaN
# 186042      NaN     NaN              NaN        NaN        NaN
# 186548      NaN     NaN              NaN        NaN        NaN
# 186826      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1                   NaN
# 356                 NaN
# 735                 NaN
# 1433                NaN
# 1553                NaN
# ...                 ...
# 185176              NaN
# ...

# %%
all_data=all_data.dropna(how="all")
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# The date column in the dataset is in text format, your job is to convert it into date format. Also create a column named month and get the corresponding month number

# %%
all_data=all_data[all_data['Order Date'].str[0:2]!='Or']
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# Now, get the column name to the appropriate format (numeric format for relevant columns)

# %%
all_data['Quantity Ordered']=pd.to_numeric(all_data['Quantity Ordered'], errors="coerce")
all_data['Price Each']=pd.to_numeric(all_data['Price Each'], errors="coerce")
all_data
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5288\2643920740.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Quantity Ordered']=pd.to_numeric(all_data['Quantity Ordered'], errors="coerce")
# C:\Users\user\AppData\Local\Temp\ipykernel_5288\2643920740.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Price Each']=pd.to_numeric(all_data['Price Each'], errors="coerce")
#        Order ID                     Product  Quantity Ordered  Price Each  \
# ...

# %%
def get_city(address): return address.split(",")[1].strip("")

def get_state(address): return address.split(",")[2].strip("")[1]

all_data["City"]=all_data ["Purchase Address"].apply(lambda x:f"{get_city(x)}({get_state(x)})")
all_data.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5288\3105266346.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data["City"]=all_data ["Purchase Address"].apply(lambda x:f"{get_city(x)}({get_state(x)})")
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address             City
# ...

# %% [markdown]
# Now get the city name from the dataset. The result should look something like this : Dallas(TX)

# %% [markdown]
# ##### Step 3 : Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Question 1: What was the best month for sales? How much was earned that month?

# %%
all_data['Month'] = pd.to_datetime(all_data['Order Date']).dt.month
all_data.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5288\3704723626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = pd.to_datetime(all_data['Order Date']).dt.month
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address             City  \
# ...

# %%
all_data.groupby(['Month']).sum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5288\2666040485.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_data.groupby(['Month']).sum()
#        Quantity Ordered  Price Each
# Month
# 1                 10903  1811768.38
# 2                 13449  2188884.72
# 3                 17005  2791207.83
# 4                 20558  3367671.02
# 5                 18667  3135125.13
# 6                 15253  2562025.61
# 7                 16072  2632539.56
# 8                 13448  2230345.42
# 9                 13109  2084992.09
# 10                22703  3715554.83
# 11                19798  3180600.68
# 12                28114  4588415.41

# %% [markdown]
# #### Question 2: What city sold the most product?

# %% [markdown]
# #### Question 3: What time should we display advertisements to maximize likelihood of customer's buying product?

# %% [markdown]
# #### Question 4: What products are most often sold together?

# %% [markdown]
# ####  Question 5: What product sold the most? Why do you think it sold the most?
