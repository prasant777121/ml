# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
poke=pd.read_csv('pokemon.csv')

# %%
poke.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
poke.rename(columns={'against_bug':'bug',"against_dark":'dark'},inplace=True)

# %%
poke.head()
# Out:
#                      abilities  bug  dark  against_dragon  against_electric  \
# 0  ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 1  ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 2  ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 3     ['Blaze', 'Solar Power']  0.5   1.0             1.0               1.0
# 4     ['Blaze', 'Solar Power']  0.5   1.0             1.0               1.0
#
#    against_fairy  against_fight  against_fire  against_flying  against_ghost  \
# 0            0.5            0.5           2.0             2.0            1.0
# 1            0.5            0.5           2.0             2.0            1.0
# 2            0.5            0.5           2.0             2.0            1.0
# 3            0.5            1.0           0.5             1.0            1.0
# 4            0.5            1.0           0.5             1.0            1.0
#
# ...

# %%
grass=poke[ poke['type1']=="grass"]
grass.head()
# Out:
#                       abilities  bug  dark  against_dragon  against_electric  \
# 0   ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 1   ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 2   ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 42  ['Chlorophyll', 'Run Away']  1.0   1.0             1.0               0.5
# 43    ['Chlorophyll', 'Stench']  1.0   1.0             1.0               0.5
#
#     against_fairy  against_fight  against_fire  against_flying  against_ghost  \
# 0             0.5            0.5           2.0             2.0            1.0
# 1             0.5            0.5           2.0             2.0            1.0
# 2             0.5            0.5           2.0             2.0            1.0
# 42            0.5            0.5           2.0             2.0            1.0
# 43            0.5            0.5           2.0             2.0            1.0
#
# ...

# %%
fire=poke[ poke['type1']=="fire"]
fire.head()
# Out:
#                                             abilities   bug  dark  \
# 3                            ['Blaze', 'Solar Power']  0.50   1.0
# 4                            ['Blaze', 'Solar Power']  0.50   1.0
# 5                            ['Blaze', 'Solar Power']  0.25   1.0
# 36  ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...  0.50   1.0
# 37  ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...  0.50   1.0
#
#     against_dragon  against_electric  against_fairy  against_fight  \
# 3              1.0               1.0            0.5            1.0
# 4              1.0               1.0            0.5            1.0
# 5              1.0               2.0            0.5            0.5
# 36             1.0               1.0            0.5            1.0
# 37             1.0               1.0            0.5            1.0
#
#     against_fire  against_flying  against_ghost  ...  percentage_male  \
# 3            0.5             1.0            1.0  ...             88.1
# ...

# %%
sns.histplot(grass['sp_attack'])
plt.show()

# %%
grass.describe()
# Out:
#              bug       dark  against_dragon  against_electric  against_fairy  \
# count  78.000000  78.000000       78.000000         78.000000      78.000000
# mean    1.717949   0.967949        0.916667          0.532051       0.967949
# std     0.771193   0.271357        0.260078          0.147264       0.363423
# min     1.000000   0.500000        0.000000          0.000000       0.500000
# 25%     1.000000   1.000000        1.000000          0.500000       1.000000
# 50%     2.000000   1.000000        1.000000          0.500000       1.000000
# 75%     2.000000   1.000000        1.000000          0.500000       1.000000
# max     4.000000   2.000000        1.000000          1.000000       2.000000
#
#        against_fight  against_fire  against_flying  against_ghost  \
# count      78.000000     78.000000       78.000000      78.000000
# mean        0.916667      2.128205        2.038462       1.019231
# std         0.444422      0.493042        0.439667       0.219833
# ...

# %%
fire.describe()
# Out:
#              bug       dark  against_dragon  against_electric  against_fairy  \
# count  52.000000  52.000000       52.000000         52.000000      52.000000
# mean    0.456731   0.951923        1.009615          1.086538       0.572115
# std     0.154358   0.227079        0.156255          0.416817       0.187453
# min     0.250000   0.500000        0.500000          0.000000       0.250000
# 25%     0.437500   1.000000        1.000000          1.000000       0.500000
# 50%     0.500000   1.000000        1.000000          1.000000       0.500000
# 75%     0.500000   1.000000        1.000000          1.000000       0.500000
# max     1.000000   2.000000        2.000000          2.000000       1.000000
#
#        against_fight  against_fire  against_flying  against_ghost  \
# count      52.000000     52.000000       52.000000      52.000000
# mean        1.028846      0.495192        1.096154       0.971154
# std         0.362636      0.092493        0.343546       0.250753
# ...

# %%
poke.head()
# Out:
#                      abilities  bug  dark  against_dragon  against_electric  \
# 0  ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 1  ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 2  ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 3     ['Blaze', 'Solar Power']  0.5   1.0             1.0               1.0
# 4     ['Blaze', 'Solar Power']  0.5   1.0             1.0               1.0
#
#    against_fairy  against_fight  against_fire  against_flying  against_ghost  \
# 0            0.5            0.5           2.0             2.0            1.0
# 1            0.5            0.5           2.0             2.0            1.0
# 2            0.5            0.5           2.0             2.0            1.0
# 3            0.5            1.0           0.5             1.0            1.0
# 4            0.5            1.0           0.5             1.0            1.0
#
# ...

# %%
poke['is_legendary'].value_counts()
# Out:
# 0    731
# 1     70
# Name: is_legendary, dtype: int64

# %%
poke[ poke['is_legendary']==1]
# Out:
#                       abilities   bug  dark  against_dragon  against_electric  \
# 143  ['Pressure', 'Snow Cloak']  0.50   1.0             1.0               2.0
# 144      ['Pressure', 'Static']  0.50   1.0             1.0               1.0
# 145  ['Pressure', 'Flame Body']  0.25   1.0             1.0               2.0
# 149     ['Pressure', 'Unnerve']  2.00   2.0             1.0               1.0
# 150             ['Synchronize']  2.00   2.0             1.0               1.0
# ..                          ...   ...   ...             ...               ...
# 796             ['Beast Boost']  0.25   1.0             0.5               2.0
# 797             ['Beast Boost']  1.00   1.0             0.5               0.5
# 798             ['Beast Boost']  2.00   0.5             2.0               0.5
# 799             ['Prism Armor']  2.00   2.0             1.0               1.0
# 800              ['Soul-Heart']  0.25   0.5             0.0               1.0
#
# ...

# %%
x=poke[['sp_attack']]

# %%
y=poke[['is_legendary']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dtc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[213,   6],
#        [ 15,   7]], dtype=int64)

# %%
(213+7)/(213+6+7+15)
# Out:
# 0.9128630705394191

# %%
poke.head()
# Out:
#                      abilities  bug  dark  against_dragon  against_electric  \
# 0  ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 1  ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 2  ['Overgrow', 'Chlorophyll']  1.0   1.0             1.0               0.5
# 3     ['Blaze', 'Solar Power']  0.5   1.0             1.0               1.0
# 4     ['Blaze', 'Solar Power']  0.5   1.0             1.0               1.0
#
#    against_fairy  against_fight  against_fire  against_flying  against_ghost  \
# 0            0.5            0.5           2.0             2.0            1.0
# 1            0.5            0.5           2.0             2.0            1.0
# 2            0.5            0.5           2.0             2.0            1.0
# 3            0.5            1.0           0.5             1.0            1.0
# 4            0.5            1.0           0.5             1.0            1.0
#
# ...

# %%
a=poke[['sp_defense']]

# %%
b=poke[['sp_attack']]

# %%
x_train,x_test,y_train,y_test=train_test_split(a,b,test_size=0.3)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtr.predict(x_test)

# %%
y_test.head()
# Out:
#      sp_attack
# 303         40
# 661         56
# 262         30
# 77          80
# 204         60

# %%
y_pred[0:5]
# Out:
# array([54.5       , 77.66666667, 37.33333333, 77.78571429, 72.44117647])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 697.9770820521948
